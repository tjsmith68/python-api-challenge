# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
# Note: Since the same api_keys file is used for multiple activities, it should be in the 
# folder one level below this notebook
import sys
sys.path.append('../')
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 587

# %%
print("Beginning Data Retrieval")
print("---------------------------------------------")

#Setup my dataframe
# City	Lat	Lng	Max Temp	Humidity	Cloudiness	Wind Speed	Country	Date
cities_df = pd.DataFrame({"City": cities})
cities_df["Lat"] = 0
cities_df["Lng"] = 0
cities_df["Max Temp"] = 0
cities_df["Humidity"] = 0
cities_df["Cloudiness"] = 0
cities_df["Wind Speed"] = 0
cities_df["Country"] = ""
cities_df["Date"] = ""

url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

query_url = f"{url}appid={weather_api_key}&units={units}&q="

#loop through cities and populate dataframe as you go
#Error handling to skip cities not returning weather info
for index in range(len(cities_df)):
    city = cities_df.loc[index, 'City']
    response = requests.get(query_url + city).json()
    
    try:
        print(f"Processing Record {index} : {response['name']}")
        cities_df.loc[index, 'City'] = response['name']
        cities_df.loc[index, 'Lat'] = response['coord']['lat']
        cities_df.loc[index, 'Lng'] = response['coord']['lon']
        cities_df.loc[index, 'Max Temp'] = response['main']['temp_max']
        cities_df.loc[index, 'Humidity'] = response['main']['humidity']
        cities_df.loc[index, 'Cloudiness'] = response['clouds']['all']
        cities_df.loc[index, 'Wind Speed'] = response['wind']['speed']
        cities_df.loc[index, 'Country'] = response['sys']['country']
        cities_df.loc[index, 'Date'] = response['dt']
        
    except (KeyError, IndexError):
        print(f"Missing result... skipping {city}.")



cities_df
# Out:
# Beginning Data Retrieval
# ---------------------------------------------
# Missing result... skipping chilac.
# Processing Record 1 : Hamilton
# Processing Record 2 : Dikson
# Processing Record 3 : Sālūmbar
# Processing Record 4 : Rikitea
# Processing Record 5 : Punta Arenas
# Processing Record 6 : Chokurdakh
# Processing Record 7 : Shingū
# Processing Record 8 : Taltal
# Processing Record 9 : Mataura
# Processing Record 10 : Kudahuvadhoo
# Processing Record 11 : Ribeira Grande
# Processing Record 12 : Constitución
# Processing Record 13 : Ushuaia
# Processing Record 14 : São Félix do Xingu
# Processing Record 15 : Dāmghān
# Processing Record 16 : Ketchikan
# Processing Record 17 : Qasigiannguit
# Processing Record 18 : Decatur
# Missing result... skipping taolanaro.
# Processing Record 20 : Bluff
# Processing Record 21 : Puerto Ayora
# Processing Record 22 : Coyhaique
# Processing Record 23 : Albany
# Processing Record 24 : Aykhal
# Processing Record 25 : Hong Kong
# Missing result... skipping amderma.
# Processing Record 27 : Hobart
# Processing Record 28 : Pinega
# Processing Record 29 : Hermanus
# Processing Record 30 : Kapaa
# Processing Record 31 : Umluj
# Processing Record 32 : Arraial do Cabo
# Processing Record 33 : Nanortalik
# Processing Record 34 : Ilulissat
# Processing Record 35 : Jackson
# Processing Record 36 : Gīdam
# Processing Record 37 : Cape Girardeau
# Processing Record 38 : Marsh Harbour
# Processing Record 39 : Vaini
# Processing Record 40 : Airai
# Processing Record 41 : Cape Town
# Processing Record 42 : Torbay
# Processing Record 43 : Byron Bay
# Processing Record 44 : Upernavik
# Processing Record 45 : Lebu
# Processing Record 46 : Mount Isa
# Processing Record 47 : Carnarvon
# Processing Record 48 : Geraldton
# Processing Record 49 : Pundaguitan
# Processing Record 50 : Bethel
# Missing result... skipping nizhneyansk.
# Processing Record 52 : George Town
# Processing Record 53 : Biltine
# Processing Record 54 : Havøysund
# Processing Record 55 : Leh
# Processing Record 56 : Cayenne
# Processing Record 57 : Bogandinskiy
# Processing Record 58 : Nantucket
# Processing Record 59 : Lichinga
# Processing Record 60 : Qaanaaq
# Processing Record 61 : Bambous Virieux
# Missing result... skipping kegayli.
# Processing Record 63 : Port Alfred
# Processing Record 64 : Kristiansund
# Processing Record 65 : Vardø
# Processing Record 66 : Cidreira
# Processing Record 67 : Avarua
# Processing Record 68 : Port Lincoln
# Processing Record 69 : Ko Samui
# Processing Record 70 : Rabat
# Processing Record 71 : Don Luan
# Processing Record 72 : Port Hawkesbury
# Processing Record 73 : Lompoc
# Processing Record 74 : Te Anau
# Processing Record 75 : Coquimbo
# Processing Record 76 : Mīrābād
# Processing Record 77 : Aklavik
# Processing Record 78 : Mount Gambier
# Missing result... skipping dalinghe.
# Processing Record 80 : Gravdal
# Processing Record 81 : Arroio Grande
# Processing Record 82 : Yellowknife
# Processing Record 83 : La Libertad
# Missing result... skipping sentyabrskiy.
# Processing Record 85 : Sterling
# Processing Record 86 : Butaritari
# Processing Record 87 : Saint Paul Harbor
# Processing Record 88 : Ābyek
# Processing Record 89 : Herat Province
# Processing Record 90 : Castro
# Processing Record 91 : Naze
# Missing result... skipping belushya guba.
# Processing Record 93 : Macao
# Processing Record 94 : Aketi
# Processing Record 95 : Los Llanos de Aridane
# Missing result... skipping illoqqortoormiut.
# Processing Record 97 : Rocha
# Processing Record 98 : Cururupu
# Processing Record 99 : Hofn
# Processing Record 100 : Srednekolymsk
# Processing Record 101 : Kruisfontein
# Missing result... skipping palabuhanratu.
# Processing Record 103 : Smithers
# Processing Record 104 : Begichevskiy
# Processing Record 105 : Port Hardy
# Processing Record 106 : Amapá
# Processing Record 107 : Esperance
# Processing Record 108 : Muros
# Processing Record 109 : East London
# Processing Record 110 : New Norfolk
# Processing Record 111 : Nabire
# Processing Record 112 : Pisco
# Processing Record 113 : Busselton
# Processing Record 114 : Taoudenni
# Processing Record 115 : Quirinópolis
# Missing result... skipping yeletskiy.
# Processing Record 117 : Baghlan
# Processing Record 118 : Hualmay
# Processing Record 119 : Conceição do Araguaia
# Processing Record 120 : Ponta do Sol
# Processing Record 121 : Iqaluit
# Processing Record 122 : Thompson
# Processing Record 123 : Sambava
# Processing Record 124 : Kavaratti
# Processing Record 125 : Hilo
# Processing Record 126 : Hammerfest
# Processing Record 127 : Evensk
# Processing Record 128 : Jumla
# Processing Record 129 : Port Elizabeth
# Missing result... skipping vitimskiy.
# Missing result... skipping saleaula.
# Processing Record 132 : Thinadhoo
# Processing Record 133 : Along
# Processing Record 134 : Kainantu
# Processing Record 135 : Santa Maria
# Processing Record 136 : Wanning
# Processing Record 137 : Souillac
# Processing Record 138 : Chernyshevskiy
# Processing Record 139 : Kaitangata
# Processing Record 140 : Flin Flon
# Processing Record 141 : Beloha
# Processing Record 142 : Imeni Poliny Osipenko
# Processing Record 143 : Saskylakh
# Missing result... skipping mys shmidta.
# Processing Record 145 : Zaraza
# Processing Record 146 : Touros
# Processing Record 147 : Humaitá
# Processing Record 148 : Pevek
# Missing result... skipping attawapiskat.
# Missing result... skipping naftah.
# Processing Record 151 : Kahului
# Processing Record 152 : Arrondissement de Muret
# Processing Record 153 : Hay River
# Processing Record 154 : Dalupirip
# Processing Record 155 : Khatanga
# Processing Record 156 : Faanui
# Missing result... skipping ye.
# Processing Record 158 : Bereda
# Processing Record 159 : Jamestown
# Processing Record 160 : Pontal do Paraná
# Processing Record 161 : Tairua
# Processing Record 162 : Raudeberg
# Missing result... skipping bargal.
# Processing Record 164 : Vanimo
# Processing Record 165 : Barrow
# Processing Record 166 : Chui
# Processing Record 167 : La Ronge
# Processing Record 168 : Saint-Philippe
# Processing Record 169 : Takoradze
# Missing result... skipping nizhneshilovka.
# Processing Record 171 : Padang
# Processing Record 172 : Saldanha
# Processing Record 173 : Hithadhoo
# Processing Record 174 : Laas
# Processing Record 175 : Dingle
# Processing Record 176 : Luan
# Processing Record 177 : Olafsvik
# Processing Record 178 : Lüderitz
# Processing Record 179 : Morrinhos
# Processing Record 180 : Port Augusta
# Processing Record 181 : Saint George
# Processing Record 182 : Fort Nelson
# Processing Record 183 : Daru
# Processing Record 184 : Padilla
# Processing Record 185 : Xingyi
# Processing Record 186 : Lagoa
# Processing Record 187 : Kalininsk
# Processing Record 188 : Buchanan
# Processing Record 189 : Ilhabela
# Processing Record 190 : Nikolskoye
# Processing Record 191 : Atuona
# Processing Record 192 : São Filipe
# Processing Record 193 : Port Blair
# Processing Record 194 : Eureka
# Missing result... skipping malwan.
# Processing Record 196 : Tessalit
# Processing Record 197 : Calintaan
# Processing Record 198 : Port Hedland
# Processing Record 199 : Isangel
# Processing Record 200 : Talcahuano
# Processing Record 201 : Quatre Cocos
# Missing result... skipping vaitupu.
# Processing Record 203 : Westport
# Processing Record 204 : Borgarnes
# Processing Record 205 : Hasaki
# Processing Record 206 : Takaka
# Processing Record 207 : Buala
# Missing result... skipping lolua.
# Processing Record 209 : Katsuura
# Processing Record 210 : Mar del Plata
# Processing Record 211 : Eirunepé
# Processing Record 212 : Dauphin
# Processing Record 213 : Ostrovnoy
# Processing Record 214 : Ormara
# Processing Record 215 : Lantana
# Processing Record 216 : Kokopo
# Processing Record 217 : Tasiilaq
# Processing Record 218 : Saint-Médard-en-Jalles
# Missing result... skipping vestbygda.
# Processing Record 220 : Arrondissement de Limoges
# Processing Record 221 : Kiunga
# Processing Record 222 : Mahébourg
# Processing Record 223 : Mattru
# Processing Record 224 : Riviere-au-Renard
# Processing Record 225 : Cabo San Lucas
# Processing Record 226 : Kongolo
# Processing Record 227 : Lakes Entrance
# Processing Record 228 : Gunjur
# Processing Record 229 : Bengkulu
# Missing result... skipping barentsburg.
# Processing Record 231 : Kingsland
# Processing Record 232 : Riyadh
# Processing Record 233 : Bermeo
# Processing Record 234 : Caravelas
# Missing result... skipping yefira.
# Processing Record 236 : Shimsk
# Processing Record 237 : Sola
# Missing result... skipping haibowan.
# Processing Record 239 : Longyearbyen
# Processing Record 240 : Marawi
# Processing Record 241 : Sungai Penuh
# Processing Record 242 : Manggar
# Processing Record 243 : Sitka
# Processing Record 244 : Clyde River
# Processing Record 245 : Bintulu
# Processing Record 246 : Nānākuli
# Processing Record 247 : Storsteinnes
# Processing Record 248 : Loukhi
# Processing Record 249 : Mazamari
# Processing Record 250 : Ixtapa
# Processing Record 251 : Juneau
# Processing Record 252 : Ngunguru
# Processing Record 253 : Catarman
# Processing Record 254 : Severo-Kuril'sk
# Processing Record 255 : Toora-Khem
# Processing Record 256 : Flinders
# Processing Record 257 : Coihueco
# Processing Record 258 : Māngrol
# Processing Record 259 : Presidente Médici
# Processing Record 260 : Richards Bay
# Processing Record 261 : Yining
# Processing Record 262 : Palmer
# Processing Record 263 : San Patricio
# Processing Record 264 : Grindavik
# Processing Record 265 : Sandnessjøen
# Processing Record 266 : Kemijärvi
# Processing Record 267 : Asău
# Processing Record 268 : Mandalgovi
# Processing Record 269 : Buritizeiro
# Processing Record 270 : Bredasdorp
# Processing Record 271 : Nhulunbuy
# Processing Record 272 : Tautira
# Processing Record 273 : Itamarandiba
# Processing Record 274 : San Juan
# Processing Record 275 : Totness
# Processing Record 276 : Mafinga
# Processing Record 277 : Dalbandin
# Processing Record 278 : Sobolevo
# Missing result... skipping tumannyy.
# Processing Record 280 : Moba
# Processing Record 281 : Pandan Niog
# Processing Record 282 : Davila
# Processing Record 283 : Belmonte
# Processing Record 284 : Cuamba
# Processing Record 285 : Tallahassee
# Processing Record 286 : Nuoro
# Processing Record 287 : Port-Cartier
# Processing Record 288 : Banda Aceh
# Processing Record 289 : Road Town
# Processing Record 290 : Werda
# Processing Record 291 : Ballarat
# Processing Record 292 : Moerai
# Processing Record 293 : Baykit
# Processing Record 294 : Punta Alta
# Processing Record 295 : Béjar
# Processing Record 296 : Yashalta
# Processing Record 297 : Chinsali
# Processing Record 298 : Camacha
# Processing Record 299 : Nuevitas
# Processing Record 300 : Río Gallegos
# Processing Record 301 : Port Macquarie
# Processing Record 302 : Norman Wells
# Processing Record 303 : Bubaque
# Processing Record 304 : São João da Barra
# Processing Record 305 : Poum
# Processing Record 306 : Pemangkat
# Missing result... skipping tsihombe.
# Processing Record 308 : Pathein
# Processing Record 309 : Warmbad
# Processing Record 310 : College
# Processing Record 311 : Atar
# Processing Record 312 : Ambanja
# Missing result... skipping sorvag.
# Processing Record 314 : Chishtian
# Processing Record 315 : Provideniya
# Processing Record 316 : Tuatapere
# Processing Record 317 : Mopti
# Processing Record 318 : Tromsø
# Processing Record 319 : Codrington
# Processing Record 320 : Reserva
# Processing Record 321 : Esim
# Processing Record 322 : Lady Frere
# Processing Record 323 : Tottori-shi
# Processing Record 324 : Taylor
# Processing Record 325 : Tabou
# Processing Record 326 : Karratha
# Processing Record 327 : Denpasar
# Processing Record 328 : Egvekinot
# Processing Record 329 : Okhotsk
# Processing Record 330 : Husavik
# Processing Record 331 : Ape
# Processing Record 332 : Qandala
# Processing Record 333 : Alofi
# Missing result... skipping taburi.
# Processing Record 335 : Saint-Joseph
# Processing Record 336 : San Andrés
# Processing Record 337 : Sørland
# Processing Record 338 : Barcelos
# Processing Record 339 : Harper
# Processing Record 340 : Xiaoshan
# Processing Record 341 : Narsaq
# Missing result... skipping toliary.
# Missing result... skipping aflu.
# Processing Record 344 : The Pas
# Processing Record 345 : Murray Bridge
# Processing Record 346 : Broome
# Processing Record 347 : Pitimbu
# Processing Record 348 : Puerto Carreño
# Processing Record 349 : Rio Grande
# Processing Record 350 : Auki
# Processing Record 351 : Serramanna
# Processing Record 352 : Samarai
# Processing Record 353 : Mehamn
# Processing Record 354 : Tamiahua
# Processing Record 355 : Guerrero Negro
# Processing Record 356 : Lincoln
# Processing Record 357 : Petropavlovsk-Kamchatskiy
# Missing result... skipping nagsabaran.
# Processing Record 359 : Tateyama
# Processing Record 360 : Bulgan
# Processing Record 361 : Aiquile
# Processing Record 362 : Pangody
# Processing Record 363 : Salalah
# Processing Record 364 : Klaksvík
# Processing Record 365 : Paamiut
# Processing Record 366 : Tiksi
# Processing Record 367 : Kupang
# Processing Record 368 : Boguchany
# Processing Record 369 : Sibolga
# Processing Record 370 : Kirakira
# Processing Record 371 : Zhigansk
# Processing Record 372 : Tiarei
# Processing Record 373 : Saint-Pierre
# Processing Record 374 : Atherton
# Processing Record 375 : Bundaberg
# Processing Record 376 : Red Bluff
# Processing Record 377 : Faya
# Processing Record 378 : Inuvik
# Processing Record 379 : Cherskiy
# Processing Record 380 : Muzhi
# Processing Record 381 : Goderich
# Processing Record 382 : Arrondissement de Cognac
# Processing Record 383 : Nuuk
# Processing Record 384 : Jinchang
# Processing Record 385 : Giyani
# Processing Record 386 : Mbanza-Ngungu
# Processing Record 387 : Angoche
# Missing result... skipping braslav.
# Processing Record 389 : Boa Vista
# Processing Record 390 : Nanga Eboko
# Processing Record 391 : Hambantota
# Processing Record 392 : Fukuechō
# Processing Record 393 : Norden
# Processing Record 394 : Zhangaözen
# Processing Record 395 : Bathsheba
# Processing Record 396 : Avera
# Processing Record 397 : Las Palmas
# Processing Record 398 : Dunedin
# Processing Record 399 : Ponta Delgada
# Processing Record 400 : Høyanger
# Processing Record 401 : Hof
# Processing Record 402 : Eyl
# Processing Record 403 : Bredy
# Processing Record 404 : Lingyuan
# Processing Record 405 : Noshiro
# Processing Record 406 : Portland
# Processing Record 407 : Leshukonskoye
# Processing Record 408 : Viedma
# Processing Record 409 : Portobelo
# Processing Record 410 : Parczew
# Processing Record 411 : Tsogni
# Processing Record 412 : Leningradskiy
# Processing Record 413 : Fortuna
# Processing Record 414 : Sinnamary
# Processing Record 415 : Praia
# Processing Record 416 : Mocuba
# Processing Record 417 : Kumul
# Processing Record 418 : Rawson
# Processing Record 419 : Buinsk
# Processing Record 420 : Tuktoyaktuk
# Processing Record 421 : Ankazoabo
# Processing Record 422 : Luena
# Processing Record 423 : Pozo Colorado
# Processing Record 424 : Bayjī
# Processing Record 425 : Kulevcha
# Processing Record 426 : Talnakh
# Processing Record 427 : Kandi
# Processing Record 428 : Jimeta
# Processing Record 429 : La Paz
# Processing Record 430 : Arlit
# Processing Record 431 : Selma
# Processing Record 432 : Beyneu
# Processing Record 433 : Dongsheng
# Processing Record 434 : Trebinje
# Processing Record 435 : Mitsamiouli
# Processing Record 436 : Businga
# Processing Record 437 : Livramento
# Processing Record 438 : Palmerston
# Processing Record 439 : Kuril'sk
# Processing Record 440 : Hengshui
# Processing Record 441 : Cranbourne
# Processing Record 442 : Bandarbeyla
# Processing Record 443 : Sinaloa
# Processing Record 444 : Ternate
# Processing Record 445 : Sovetskiy
# Processing Record 446 : Orzhytsya
# Processing Record 447 : Ochamchira
# Processing Record 448 : Sakakah
# Processing Record 449 : Moyo
# Processing Record 450 : Pochutla
# Processing Record 451 : Martil
# Processing Record 452 : Carlsbad
# Processing Record 453 : Biscarrosse
# Missing result... skipping samalaeulu.
# Processing Record 455 : Nueve de Julio
# Processing Record 456 : Perehonivka
# Processing Record 457 : Itarema
# Processing Record 458 : Anzio
# Processing Record 459 : Shumskiy
# Processing Record 460 : Prieska
# Processing Record 461 : Puerto Palomas
# Missing result... skipping lemesos.
# Processing Record 463 : Diego de Almagro
# Processing Record 464 : Dicabisagan
# Processing Record 465 : Rio Branco
# Processing Record 466 : Khasan
# Processing Record 467 : Rafaela
# Processing Record 468 : Menongue
# Processing Record 469 : Lorengau
# Processing Record 470 : Erenhot
# Processing Record 471 : Robertsport
# Processing Record 472 : Bukama
# Processing Record 473 : Vao
# Missing result... skipping rungata.
# Processing Record 475 : Uyuni
# Processing Record 476 : Lac-Mégantic
# Processing Record 477 : Dhāri
# Processing Record 478 : Canguçu
# Missing result... skipping umm durman.
# Processing Record 480 : Namatanai
# Processing Record 481 : Dingzhou
# Processing Record 482 : Meulaboh
# Processing Record 483 : Srandakan
# Processing Record 484 : Thunder Bay
# Missing result... skipping ust-kamchatsk.
# Processing Record 486 : Cuauhtémoc
# Processing Record 487 : Maceió
# Processing Record 488 : Galliate
# Processing Record 489 : Blagoyevo
# Processing Record 490 : Manado
# Processing Record 491 : Arcata
# Processing Record 492 : Swabi
# Missing result... skipping temaraia.
# Processing Record 494 : Soe
# Missing result... skipping mouzakion.
# Processing Record 496 : Medicine Hat
# Processing Record 497 : Yulara
# Processing Record 498 : Vostok
# Processing Record 499 : Kamenka
# Missing result... skipping grand river south east.
# Processing Record 501 : Tolaga Bay
# Processing Record 502 : Manali
# Processing Record 503 : Southbridge
# Processing Record 504 : Bloemfontein
# Processing Record 505 : Santo Domingo
# Processing Record 506 : Ola
# Processing Record 507 : Tilichiki
# Processing Record 508 : Union
# Processing Record 509 : Mikkeli
# Processing Record 510 : Kelsterbach
# Processing Record 511 : St. George's
# Processing Record 512 : Makakilo City
# Processing Record 513 : Mollendo
# Processing Record 514 : Svetlaya
# Processing Record 515 : Zhangjiakou
# Processing Record 516 : Malindi
# Processing Record 517 : Ancud
# Processing Record 518 : Banes
# Processing Record 519 : Zemio
# Processing Record 520 : Ambon City
# Missing result... skipping dzhusaly.
# Processing Record 522 : Acapulco de Juárez
# Processing Record 523 : Takapau
# Processing Record 524 : Kidal
# Processing Record 525 : Hatillo
# Processing Record 526 : Sinait
# Processing Record 527 : Tahe
# Processing Record 528 : Vila
# Processing Record 529 : Batié
# Processing Record 530 : Sanguéya
# Processing Record 531 : Robertson
# Processing Record 532 : Mūlki
# Processing Record 533 : Mabopane
# Processing Record 534 : Whitehorse
# Processing Record 535 : San Quintín
# Processing Record 536 : Pinheiro
# Processing Record 537 : Bamnet Narong
# Processing Record 538 : Belaya Gora
# Processing Record 539 : Mossamedes
# Missing result... skipping talawdi.
# Processing Record 541 : Turukhansk
# Missing result... skipping sinkat.
# Processing Record 543 : Sokolo
# Processing Record 544 : Tombouctou
# Processing Record 545 : Balsas
# Processing Record 546 : Salinas
# Processing Record 547 : Mandiana
# Processing Record 548 : Katangli
# Processing Record 549 : Pangnirtung
# Processing Record 550 : Valle de Allende
# Processing Record 551 : Bambari
# Processing Record 552 : Great Falls
# Processing Record 553 : Arman'
# Processing Record 554 : Meiktila
# Processing Record 555 : Martapura
# Processing Record 556 : Bhainsdehi
# Processing Record 557 : Challakere
# Processing Record 558 : Nelson Bay
# Processing Record 559 : Biu
# Processing Record 560 : Kharan
# Processing Record 561 : Bend
# Processing Record 562 : Tabuk
# Processing Record 563 : Mzimba
# Processing Record 564 : Strathpeffer
# Processing Record 565 : Ahipara
# Processing Record 566 : Novosheshminsk
# Processing Record 567 : Imbituba
# Processing Record 568 : Cumana
# Processing Record 569 : Ampanihy
# Processing Record 570 : Maniitsoq
# Processing Record 571 : Djambala
# Processing Record 572 : Poso
# Processing Record 573 : Adrar
# Processing Record 574 : Burnie
# Processing Record 575 : Lieksa
# Processing Record 576 : Östersund
# Processing Record 577 : Guarapari
# Processing Record 578 : Natal
# Missing result... skipping solovetskiy.
# Processing Record 580 : Monterey
# Processing Record 581 : Tashara
# Processing Record 582 : Laredo
# Processing Record 583 : Diamantino
# Processing Record 584 : Walvis Bay
# Processing Record 585 : Saint-André-Avellin
# Processing Record 586 : Mezhdurechensk
#                     City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0                 chilac   0.0000    0.0000      0.00         0           0
# 1               Hamilton  39.1834  -84.5333     73.96        47           1
# 2                 Dikson  73.5069   80.5464     27.82        57         100
# 3               Sālūmbar  24.1333   74.0500     75.33        53         100
# 4                Rikitea -23.1203 -134.9692     74.93        71           0
# ..                   ...      ...       ...       ...       ...         ...
# 582               Laredo  27.5064  -99.5075     87.80        45         100
# 583           Diamantino -14.4086  -56.4461     85.10        55          93
# 584           Walvis Bay -22.9575   14.5053     59.09        85         100
# 585  Saint-André-Avellin  45.7168  -75.0660     61.61        58         100
# 586       Mezhdurechensk  53.6942   88.0603     36.82        71          69
#
#      Wind Speed Country        Date
# 0          0.00
# 1          1.01      US  1634669631
# 2         11.86      RU  1634669156
# 3          1.70      IN  1634669632
# 4         20.42      PF  1634669090
# ..          ...     ...         ...
# 582       15.64      US  1634670052
# 583        2.95      BR  1634670065
# 584        7.49      NA  1634670066
# 585       10.38      CA  1634670066
# 586        2.82      RU  1634670066
#
# [587 rows x 9 columns]

# %%
#Remove cities with missing data
clean_city_data = cities_df[(cities_df["Lat"] != 0)] 

#Remove cities with Humidity > 100
clean_city_data = clean_city_data[(cities_df["Humidity"] <= 100)]

clean_city_data
# Out:
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
#                     City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 1               Hamilton  39.1834  -84.5333     73.96        47           1
# 2                 Dikson  73.5069   80.5464     27.82        57         100
# 3               Sālūmbar  24.1333   74.0500     75.33        53         100
# 4                Rikitea -23.1203 -134.9692     74.93        71           0
# 5           Punta Arenas -53.1500  -70.9167     62.71        51          75
# ..                   ...      ...       ...       ...       ...         ...
# 582               Laredo  27.5064  -99.5075     87.80        45         100
# 583           Diamantino -14.4086  -56.4461     85.10        55          93
# 584           Walvis Bay -22.9575   14.5053     59.09        85         100
# 585  Saint-André-Avellin  45.7168  -75.0660     61.61        58         100
# 586       Mezhdurechensk  53.6942   88.0603     36.82        71          69
#
#      Wind Speed Country        Date
# 1          1.01      US  1634669631
# 2         11.86      RU  1634669156
# 3          1.70      IN  1634669632
# 4         20.42      PF  1634669090
# 5         35.68      CL  1634669094
# ..          ...     ...         ...
# 582       15.64      US  1634670052
# 583        2.95      BR  1634670065
# 584        7.49      NA  1634670066
# 585       10.38      CA  1634670066
# 586        2.82      RU  1634670066
#
# [541 rows x 9 columns]

# %%
#output clean city data to a csv file


clean_city_data.to_csv('../output_data/citydata.csv', index=False)

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
x_values = clean_city_data["Lat"].values
y_values = clean_city_data["Max Temp"].values

plt.scatter(x_values, y_values)
plt.title("Max Temperature vs. City Latitude")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
x_values = clean_city_data["Lat"].values
y_values = clean_city_data["Humidity"].values

plt.scatter(x_values, y_values)
plt.title("Humidity (%) vs. City Latitude")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
x_values = clean_city_data["Lat"].values
y_values = clean_city_data["Cloudiness"].values

plt.scatter(x_values, y_values)
plt.title("Cloudiness (%) vs. City Latitude")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
x_values = clean_city_data["Lat"].values
y_values = clean_city_data["Wind Speed"].values

plt.scatter(x_values, y_values)
plt.title("Wind Speed (mph) vs. City Latitude")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.show()

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Get subset of clean data for Northern Hemisphere

clean_data_north = cities_df[(cities_df["Lat"] > 0)] 

x_values = clean_data_north["Lat"].values
y_values = clean_data_north["Max Temp"].values

plt.scatter(x_values, y_values,color="blue")
plt.title("Max Temperature vs. City Latitude (Northern Hemisphere)")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")


(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,0),fontsize=15,color="red")

print(f"The r-squared is: {rvalue**2}")

plt.show()
# Out:
# The r-squared is: 0.7401853849927674

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Get subset of clean data for Northern Hemisphere

clean_data_south = cities_df[(cities_df["Lat"] < 0)] 

x_values = clean_data_south["Lat"].values
y_values = clean_data_south["Max Temp"].values

plt.scatter(x_values, y_values,color="blue")
plt.title("Max Temperature vs. City Latitude (Southern Hemisphere)")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")


(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,90),fontsize=15,color="red")

print(f"The r-squared is: {rvalue**2}")

plt.show()
# Out:
# The r-squared is: 0.4762119003818335

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Get subset of clean data for Northern Hemisphere

clean_data_north = cities_df[(cities_df["Lat"] > 0)] 

x_values = clean_data_north["Lat"].values
y_values = clean_data_north["Humidity"].values

plt.scatter(x_values, y_values,color="blue")
plt.title("Humidity vs. City Latitude (Northern Hemisphere)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")


(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(35,10),fontsize=15,color="red")

print(f"The r-squared is: {rvalue**2}")

plt.show()
# Out:
# The r-squared is: 0.012505631886859906

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Get subset of clean data for Northern Hemisphere

clean_data_south = cities_df[(cities_df["Lat"] < 0)] 

x_values = clean_data_south["Lat"].values
y_values = clean_data_south["Humidity"].values

plt.scatter(x_values, y_values,color="blue")
plt.title("Humidity vs. City Latitude (Southern Hemisphere)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")


(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,2),fontsize=15,color="red")

print(f"The r-squared is: {rvalue**2}")

plt.show()
# Out:
# The r-squared is: 0.05240790771073081

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Get subset of clean data for Northern Hemisphere

clean_data_north = cities_df[(cities_df["Lat"] > 0)] 

x_values = clean_data_north["Lat"].values
y_values = clean_data_north["Cloudiness"].values

plt.scatter(x_values, y_values,color="blue")
plt.title("Cloudiness vs. City Latitude (Northern Hemisphere)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")


(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(20,30),fontsize=15,color="red")

print(f"The r-squared is: {rvalue**2}")

plt.show()
# Out:
# The r-squared is: 0.005042766164846109

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Get subset of clean data for Northern Hemisphere

clean_data_south = cities_df[(cities_df["Lat"] < 0)] 

x_values = clean_data_south["Lat"].values
y_values = clean_data_south["Max Temp"].values

plt.scatter(x_values, y_values,color="blue")
plt.title("Max Temperature vs. City Latitude (Southern Hemisphere)")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")


(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-35,40),fontsize=15,color="red")

print(f"The r-squared is: {rvalue**2}")

plt.show()
# Out:
# The r-squared is: 0.4762119003818335

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Get subset of clean data for Northern Hemisphere

clean_data_north = cities_df[(cities_df["Lat"] > 0)] 

x_values = clean_data_north["Lat"].values
y_values = clean_data_north["Wind Speed"].values

plt.scatter(x_values, y_values,color="blue")
plt.title("Wind Speed vs. City Latitude (Northern Hemisphere)")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")


(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,27),fontsize=15,color="red")

print(f"The r-squared is: {rvalue**2}")

plt.show()
# Out:
# The r-squared is: 0.042937830852265414

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Get subset of clean data for Northern Hemisphere

clean_data_south = cities_df[(cities_df["Lat"] < 0)] 

x_values = clean_data_south["Lat"].values
y_values = clean_data_south["Wind Speed"].values

plt.scatter(x_values, y_values,color="blue")
plt.title("Wind Speed vs. City Latitude (Southern Hemisphere)")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")


(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,27),fontsize=15,color="red")

print(f"The r-squared is: {rvalue**2}")

plt.show()
# Out:
# The r-squared is: 0.06432088520311638
